# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sc
import geopandas as gpd
import contextily as cx
import folium

# %%
path=('Data/centros-de-salud/Centros de Salud/Centros_de_salud.shp')

# %%
df_sk1 = gpd.read_file(path)

# %%
Out_Op=df_sk1[df_sk1['ESTATU_OPE']!='FUERA DE OPERACIÓN (TOTAL O PARCIAL)'].geometry
geo_df_list=[[point.xy[1][0],point.xy[0][0]] for point in Out_Op]

# %%
skt_points=[point for point in geo_df_list if point not in geo_df_list]

# %%
skt_points=[point for point in geo_df_list]

# %%
Out_Op=df_sk1[df_sk1['ESTATU_OPE']!='FUERA DE OPERACIÓN (TOTAL O PARCIAL)'].geometry
geo_df_list=[[point.xy[1][0],point.xy[0][0]] for point in Out_Op]
skt_points=[point for point in geo_df_list]

# %%
skt_points_trans=[]
A0=float('inf')
B0=-float('inf')
A1=float('inf')
B1=-float('inf')

for i in range(len(skt_points)):
    skt_points_trans.append([skt_points[i][1],skt_points[i][0]])
    if skt_points[i][1]< A0:
        A0=skt_points[i][1]
    if skt_points[i][1]> B0:
        B0=skt_points[i][1]
    if skt_points[i][0]< A1:
        A1=skt_points[i][0]
    if skt_points[i][0]> B0:
        B1=skt_points[i][0]

# %%
from matplotlib.collections import LineCollection

# %%
path4=('Data/alcaldias_cdmx.shp')
df_sk4 = gpd.read_file(path4)

# %%
import numpy as np
from scipy.spatial import Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt

points = skt_points_trans
vor = Voronoi(points)

fig, ax = plot.subplots(figsize =(10,10))
fig2=voronoi_plot_2d(vor,ax=ax,show_vertices=False, line_colors='k',line_width=1, line_alpha=0.1)
df_sk4.plot(color='grey', alpha=0.2,ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9928\3197671623.py in <module>
#       6 vor = Voronoi(points)
#       7
# ----> 8 fig, ax = plot.subplots(figsize =(10,10))
#       9 fig2=voronoi_plot_2d(vor,ax=ax,show_vertices=False, line_colors='k',line_width=1, line_alpha=0.1)
#      10 df_sk4.plot(color='grey', alpha=0.2,ax=ax)
#
# NameError: name 'plot' is not defined

# %%
Out_Op=df_sk1[df_sk1['ESTATU_OPE']=='FUERA DE OPERACIÓN (TOTAL O PARCIAL)'].geometry
geo_df_list_menus=[[point.xy[1][0],point.xy[0][0]] for point in Out_Op]

# %%
map = folium.Map(location=[19.432, -99.133], tiles="OpenStreetMap", zoom_start=9, max_zoom = 16, min_zoom=10)

# Se crea una lista con los puntos coordenadas

geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in df_sk1.geometry]

#print(geo_df_list)

#se itera en el conjunto de puntos
for coordinates in geo_df_list:
    
    if coordinates in geo_df_list_menus:
         folium.CircleMarker(
        location=coordinates,
        radius=2.5,
        color="#E7625F",
        fill=True,
        fill_color="#E7625F",).add_to(map)
    else:    
    
        folium.CircleMarker(
        location=coordinates,
        radius=5,
        color="#3186cc",
        fill=True,
        fill_color="#3186cc",).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from geojson import FeatureCollection, Feature, Polygon

# %%
m=folium.Map(location=[19.432, -99.133], tiles="OpenStreetMap", zoom_start=9, max_zoom = 16, min_zoom=10)
point_voronoi_list = []
feature_list = []
for region in range(len(vor.regions)-1):
    vertex_list = []
    for x in vor.regions[region]:
        if x == -1:
            break;
        else:
            #Get the vertex out of the list, and flip the order for folium:
            vertex = vor.vertices[x]
            vertex = (vertex[1], vertex[0])
        vertex_list.append(vertex)
    #Save the vertex list as a polygon and then add to the feature_list:
        polygon = Polygon([vertex_list])

    feature = Feature(geometry=polygon, properties={})
    folium.Polygon(polygon['coordinates']).add_to(m)
    #print(polygon['coordinates'])
    feature_list.append(feature)
#geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in df_sk1.geometry]

#print(geo_df_list)

#se itera en el conjunto de puntos
for coordinates in skt_points:
    folium.CircleMarker(location=coordinates, radius=5,color="#E7625F", fill=True, fill_color="#E7625F",).add_to(m)

# %%
#skt_points

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
### Centros de Salud con Hospitalización

# %%
df_sk1 = gpd.read_file(path)

# %%
df_sk1

# %%
df_sk1=df_sk1[df_sk1['tipo_centr'] =='T-II']
df_sk1=df_sk1[df_sk1['ESTATU_OPE']!='FUERA DE OPERACIÓN (TOTAL O PARCIAL)']
Out_Op=df_sk1[df_sk1['ESTATU_OPE']!='FUERA DE OPERACIÓN (TOTAL O PARCIAL)'].geometry
geo_df_list=[[point.xy[1][0],point.xy[0][0]] for point in Out_Op]

# %%
df_sk_new=df_sk1

# %%
CMpoints=[]
for i in range(len(df_sk_new)): 
    CMpoints.append([df_sk_new.LONGITUD.iloc[i],df_sk_new.LATITUD.iloc[i]])

# %%
skt_points=[point for point in geo_df_list]

# %%
skt_points_trans=[]
A0=float('inf')
B0=-float('inf')
A1=float('inf')
B1=-float('inf')

for i in range(len(skt_points)):
    skt_points_trans.append([skt_points[i][1],skt_points[i][0]])
    if skt_points[i][1]< A0:
        A0=skt_points[i][1]
    if skt_points[i][1]> B0:
        B0=skt_points[i][1]
    if skt_points[i][0]< A1:
        A1=skt_points[i][0]
    if skt_points[i][0]> B0:
        B1=skt_points[i][0]

# %%
points = skt_points_trans
vor = Voronoi(points)

fig, ax = plot.subplots(figsize =(10,10))
fig2=voronoi_plot_2d(vor,ax=ax,show_vertices=False, line_colors='k',line_width=1, line_alpha=0.1)
df_sk4.plot(color='grey', alpha=0.2,ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9928\2374572861.py in <module>
#       2 vor = Voronoi(points)
#       3
# ----> 4 fig, ax = plot.subplots(figsize =(10,10))
#       5 fig2=voronoi_plot_2d(vor,ax=ax,show_vertices=False, line_colors='k',line_width=1, line_alpha=0.1)
#       6 df_sk4.plot(color='grey', alpha=0.2,ax=ax)
#
# NameError: name 'plot' is not defined

# %%
n=folium.Map(location=[19.432, -99.133], tiles="OpenStreetMap", zoom_start=9, max_zoom = 16, min_zoom=10)
point_voronoi_list = []
feature_list = []
for region in range(len(vor.regions)-1):
    vertex_list = []
    for x in vor.regions[region]:
        if x == -1:
            break;
        else:
            
            vertex = vor.vertices[x]
            vertex = (vertex[1], vertex[0])
        vertex_list.append(vertex)
    
        polygon = Polygon([vertex_list])

    feature = Feature(geometry=polygon, properties={})
    folium.Polygon(polygon['coordinates']).add_to(n)
    #print(polygon['coordinates'])
    feature_list.append(feature)
#geo_df_list = [[point.xy[1][0], point.xy[0][0]] for point in df_sk1.geometry]

#print(geo_df_list)

#se itera en el conjunto de puntos
for coordinates in skt_points:
    folium.CircleMarker(location=coordinates, radius=5,color="#E7625F", fill=True, fill_color="#E7625F",).add_to(n)

# %%
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Elección de incidentes

# %%
import random

# %%
vec_acc=[(-99.123774, 19.42265),(-99.09144905, 19.4084474),(-99.19236, 19.37147),(-99.14089, 19.37593),(-99.133324, 19.308644),(-99.212553, 19.379281),(-99.18096, 19.3628),
(-99.18096283, 19.36299645),
(-99.155138, 19.370078),
(-99.012354, 19.285714),
(-99.05091, 19.3253),
(-99.02579, 19.35542),
(-99.04144, 19.29424),
(-99.055159, 19.374974),
(-99.158311, 19.312336),
(-99.149745, 19.435529),
(-99.21208072, 19.43539737),
(-99.0561399, 19.42185551),
(-99.164734, 19.448173),
(-99.197551, 19.431745),
(-99.151837, 19.488889),
(-99.142107, 19.426512),
(-99.04061448, 19.29653377),
(-99.11439, 19.455851),
(-99.11450601, 19.45532062),
(-99.09652348, 19.37745579),
(-99.153621, 19.463303),
(-99.264105, 19.339476),
(-99.15993553, 19.43056932),
(-99.14505155, 19.35357359),
(-99.179223, 19.396893),
(-99.221237, 19.364574),
(-99.13557323, 19.43419431),
(-99.155037, 19.438306),
(-99.147325, 19.435149),
(-99.11151, 19.38645),
(-99.04792, 19.4423),
(-99.05417, 19.31135),
(-99.18284, 19.48403),
(-99.131262, 19.502888),
(-99.057911, 19.34697),
(-99.112593, 19.440521),
(-99.152781, 19.539494),
(-99.104793, 19.40766),
(-99.203555, 19.50044),
(-99.203574, 19.425382),
(-99.08644235, 19.47995444),
(-99.08057462, 19.45034471),
(-99.05776668, 19.35912234),
(-99.12453, 19.45188),
(-99.210255, 19.266838),
(-99.17347707, 19.4301889),
(-99.113743, 19.356807),
(-99.19125546, 19.36476578),
(-99.24759, 19.35982),
(-99.247225, 19.360025),
(-99.126405, 19.461152),
(-99.16511, 19.370537),
(-99.11979459, 19.36590092),
(-99.27996, 19.34518),
(-99.17128, 19.434231),
(-99.156383, 19.53447),
(-99.154045, 19.483007)]

# %%
point=random.choice(vec_acc)

# %%
point
# Out:
# (-99.055159, 19.374974)

# %%
#skt_points

# %%
#Funciones de distancia

# %%
def dista_eclidiana(c,p):
    'Regresa la distancia euclidiana entre ambos puntos'
    dist=(((c[0]-p[0])**2)+ (c[1]-p[1])**2 )**1/2
    return dist

# %%
def dist_men(a,b,c):
    '''a,b,c -> array(1x2),array(1x2xn),array(1xn)'''    
    min_index_p=0
    dista_min_p=float('inf')
    min_index=0
    dista_min=float('inf')
    for i in range(len(b)):
        
        dist_p=c[i]*dista_eclidiana(a,b[i])
        dist=dista_eclidiana(a,b[i])
        
        if dist_p < dista_min_p:
            
            dista_min_p = dist_p
            min_index_p = i
        
        if dist< dista_min:
            dista_min = dist
            min_index = i
        
    return min_index,dista_min,min_index_p,dista_min_p

# %%
####  Caracteristicas de Hospitales

# %%
list_col=['Ocupacion','Servicios','Planta']

# %%
df_carac= pd.DataFrame(np.random.rand(len(skt_points),3), columns=list_col)

# %%
df_carac.head()
# Out:
#    Ocupacion  Servicios    Planta
# 0   0.558417   0.137841  0.681669
# 1   0.553613   0.434573  0.924411
# 2   0.660169   0.351539  0.431279
# 3   0.210488   0.056847  0.577609
# 4   0.919936   0.639471  0.020997

# %%
POND_com=np.random.rand(len(df_carac.columns))

# %%
def prom_ponder(cols,POND_com):
    '''cols,Pond_com -> df,axis'''
    larg=int(cols.shape[1])
    for i in range(larg):
        cols.iloc[:,i]=cols.iloc[:,i]*POND_com[i]
    
    return cols

# %%
df_pon=prom_ponder(df_carac,POND_com)

# %%
#Peso de cada hospital  
df_pon_n=df_pon.mean(axis=1)

# %%
for i in range(len(df_pon_n)):
    df_pon_n[i]=random.uniform(0, 1)
    #df_pon_n.append(random.uniform(5, 10))

# %%
#df_pon_n

# %%
### Distancia Menor Ponderada #######################################

# %%
acci_point=[point[1],point[0]]
acci_point
# Out:
# [19.374974, -99.055159]

# %%
new_locations=dist_men(acci_point,skt_points,df_pon_n)
new_locations
# Out:
# (16, 0.0008767096784998849, 26, 0.00011467426788480816)

# %%
df_sk1=df_sk1.reset_index()

# %%
df_sk1.loc[new_locations[0]]
# Out:
# index                               79
# ID                                  80
# NOM_ENT               CIUDAD DE MEXICO
# C__ENTIDAD                          09
# N_MUNICI                     IZTACALCO
# C_MUNI                             006
# N_LOC                        IZTACALCO
# C_LOC                             0001
# N_INSTITU          SECRETARÍA DE SALUD
# TOT_CONSU                           10
# NOM_UNIDAD       C.S.T-II RAMOS MILLÁN
# ESTATU_OPE                EN OPERACIÓN
# LONGITUD                      -99.0955
# LATITUD                        19.3862
# tipo_centr                        T-II
# geometry      POINT (-99.0955 19.3862)
# Name: 16, dtype: object

# %%
antes_CS=df_sk1.loc[new_locations[0]].values[12:14]

# %%
next_CS=df_sk1.loc[new_locations[2]].values[12:14]

# %%
antes_CS
# Out:
# array(['-99.0955', '19.3862'], dtype=object)

# %%
next_CS
# Out:
# array(['-98.9681', '19.3078'], dtype=object)

# %%
#### Mapa final

# %%
antes_CS=np.flip(antes_CS)

# %%
next_CS=np.flip(next_CS)

# %%
next_CS
# Out:
# array(['19.3078', '-98.9681'], dtype=object)

# %%
acci_point
# Out:
# [19.374974, -99.055159]

# %%
p = folium.Map(location=[19.432, -99.133], tiles="OpenStreetMap", zoom_start=9, max_zoom = 16, min_zoom=10)

# Se crea una lista con los puntos coordenadas

folium.CircleMarker( location=antes_CS,radius=2.5, color="#E7625F",fill=True, fill_color="#E7625F",).add_to(p)
folium.CircleMarker( location=next_CS,radius=2.5, color="Blue",fill=True, fill_color="#E7625F",).add_to(p)    
folium.CircleMarker( location=acci_point,radius=2.5, color="Black",fill=True, fill_color="#E7625F",).add_to(p)  
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import googlemaps

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
p
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
